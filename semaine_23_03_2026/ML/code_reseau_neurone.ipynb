# %%
import os
# Désactiver Triton qui n'est pas compatible avec RTX 5070 Ti
os.environ["TF_DISABLE_TRITON_AUTOTUNE"] = "1"
# Utiliser le fusionneur XLA standard au lieu de Triton
os.environ["XLA_FLAGS"] = "--xla_gpu_autotune_level=0"

# %%
import tensorflow as tf

# Forcer l'utilisation du CPU pour éviter les problèmes de compilation GPU
tf.config.set_visible_devices([], 'GPU')

print(tf.__version__)
print("GPU disponible :", tf.config.list_physical_devices('GPU'))
# Out:
# 2.21.0
# GPU disponible : [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from sklearn.datasets import load_iris

data = load_iris()

X = data.data
y = data.target

print(f"Données: X shape {X.shape}, y shape {y.shape}")
print(f"Nombre de classes: {len(set(y))}")

model = tf.keras.Sequential(
    [
    Input(shape=(4,)),
    Dense(128, activation="relu"),
    Dense(128, activation="relu"),
    Dense(3, activation="softmax")
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.fit(
    x=X, y=y,
    epochs=100,
    batch_size=28,
    validation_split=0.2
)
# Out:
# Données: X shape (150, 4), y shape (150,)
# Nombre de classes: 3
# Epoch 1/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - accuracy: 0.5000 - loss: 1.4963 - val_accuracy: 0.0000e+00 - val_loss: 2.4227
# Epoch 2/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5583 - loss: 0.8871 - val_accuracy: 0.0000e+00 - val_loss: 2.0173
# Epoch 3/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8667 - loss: 0.4438 - val_accuracy: 1.0000 - val_loss: 0.4246
# Epoch 4/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7000 - loss: 0.4402 - val_accuracy: 0.7333 - val_loss: 0.6213
# Epoch 5/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8750 - loss: 0.3048 - val_accuracy: 0.0000e+00 - val_loss: 0.9413
# Epoch 6/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9000 - loss: 0.2254 - val_accuracy: 0.7000 - val_loss: 0.5961
# Epoch 7/100
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9750 - loss: 0.1673 - val_accuracy: 0.9333 - val_loss: 0.3252
# ...

# %%
class MyModel(tf.keras.Model):
    def __init__(self):
        super().__init__()
        self.dense1 = Dense(4, activation="relu")
        self.dense2 = Dense(4, activation="relu")
        self.dense3 = Dense(1, activation="linear")
    def call(self, inputs):
        text, image = inputs
        x1 = self.dense1(text)
        x2 = self.dense2(image)
        x = tf.concat([x1, x2], axis=-1)
        
        return self.dense3(x)
