# %%
import sys
print(sys.executable)
# Out:
# c:\Users\benoi\miniconda3\envs\ml\python.exe

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

print("Tout fonctionne !")

df = pd.DataFrame({
    "x": np.arange(10),
    "y": np.arange(10) * 2
})

sns.lineplot(data=df, x="x", y="y")
plt.show()
# Out:
# Tout fonctionne !

# %%
import torch
print(torch.__version__)
print("GPU:", torch.cuda.is_available())
# Out:
# Running cells with 'ml (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/mnt/c/Users/benoi/Desktop/YNOV/ml/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

X = np.array([[1],[2],[3],[4]])
y = np.array([2,4,6,8])

model = LinearRegression()
model.fit(X,y)

print("Prediction pour 5 :", model.predict([[5]]))
# Out:
# Prediction pour 5 : [10.]

# %%
import tensorflow as tf

print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.21.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# GPU: []
