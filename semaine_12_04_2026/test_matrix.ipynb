# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models

matrice = np.random.uniform(size = (1,4,10))

conl = layers.Conv1D(32, 2, activation='relu')

Y = conl(matrice)

lstml = layers.LSTM(50, return_sequences = False, return_state = True)
Y, h, c = lstml(Y)

print(matrice)
print(matrice.shape)
# Out:
# [[[0.61030312 0.19385067 0.92857357 0.84070062 0.77789513 0.03449482
#    0.93057686 0.99338176 0.5364172  0.77761938]
#   [0.57867361 0.04702741 0.12978735 0.99213004 0.78190466 0.47427679
#    0.53624674 0.32768383 0.25457559 0.36953835]
#   [0.39080072 0.75758759 0.38295322 0.26987625 0.70716464 0.17027813
#    0.54510683 0.52886891 0.23122568 0.23798993]
#   [0.77951348 0.5870447  0.52018707 0.90404215 0.43580599 0.42628189
#    0.77832626 0.84991587 0.50418761 0.55103745]]]
# (1, 4, 10)
