# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models

matrice = np.random.uniform(size = (1,4,10))

conl = layers.Conv1D(32, 2, activation='relu')

Y = conl(matrice)

print(matrice)
print(matrice.shape)
# Out:
# [[[0.9747796  0.4809872  0.86019805 0.71357947 0.5319822  0.88246573
#    0.74648835 0.91073794 0.1063117  0.70652794]
#   [0.9007108  0.8544376  0.9040583  0.27282669 0.10180003 0.04819262
#    0.05064772 0.05198673 0.14686531 0.99032926]
#   [0.53224774 0.4060718  0.15838354 0.13060766 0.88417523 0.90181553
#    0.97720463 0.74576504 0.803071   0.75032805]
#   [0.16287265 0.91048275 0.70812786 0.05660851 0.63197115 0.02048398
#    0.50823766 0.83054663 0.56800311 0.91029241]]]
# (1, 4, 10)
